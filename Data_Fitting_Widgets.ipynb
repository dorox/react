# %%
import models
import matplotlib.pyplot as p

# %%
chem1 = models.Chemistry()
chem1.reaction('A+X=>B+Y')
chem1.reaction('B+A=>C+Y', k=0.1)
chem1.initial_concentrations(A=90, X=200)
chem1.time_stop = 20
_ = chem1.run()
# Out:
# run time: 0.157s

# %%
chem1.import_data('data/Expt1.csv')

# %%
chem1.plot('A', 'B', 'C')

# %%
chem1.rate_constants = [1e-7,1e-9]
chem1.rate_constants
# Out:
# [1e-07, 1e-09]

# %%
_=chem1.run()
# Out:
# run time: 0.005s

# %%
chem1.plot('A', 'B', 'C')

# %%
chem1.rate_constants = [2.30600665e-07, 3.69897732e-07]
_=chem1.run()
# Out:
# run time: 0.027s

# %%
chem1.fit()
# Out:
#  final_simplex: (array([[2.51106097e-07, 3.93445047e-07],
#        [2.51119446e-07, 3.93497042e-07],
#        [2.51116125e-07, 3.93410952e-07]]), array([1725.39739357, 1725.39739653, 1725.39743446]))
#            fun: 1725.397393566047
#        message: 'Optimization terminated successfully.'
#           nfev: 138
#            nit: 71
#         status: 0
#        success: True
#              x: array([2.51106097e-07, 3.93445047e-07])
# run time: 0.003s
#  final_simplex: (array([[2.51106097e-07, 3.93445047e-07],
#        [2.51119446e-07, 3.93497042e-07],
#        [2.51116125e-07, 3.93410952e-07]]), array([1725.39739357, 1725.39739653, 1725.39743446]))
#            fun: 1725.397393566047
#        message: 'Optimization terminated successfully.'
#           nfev: 138
#            nit: 71
#         status: 0
#        success: True
#              x: array([2.51106097e-07, 3.93445047e-07])

# %%
chem1.plot('A', 'B', 'C')

# %%
chem2 = models.Chemistry()
chem2.reaction('A+X=>B+Y', k = 2.30600665e-07)
chem2.reaction('B+A=>C+Y', k = 3.69897732e-07)
chem2.initial_concentrations(A=90, X=200)
chem2.time_stop = 20000
_=chem2.run()
# Out:
# run time: 0.004s

# %%
chem2.import_data('data/Expt1.csv')

# %%
chem2.fit()
# Out:
#  final_simplex: (array([[2.51115640e-07, 3.93491174e-07],
#        [2.51117417e-07, 3.93428697e-07],
#        [2.51104290e-07, 3.93432465e-07]]), array([1725.39737427, 1725.39741302, 1725.39741671]))
#            fun: 1725.397374270815
#        message: 'Optimization terminated successfully.'
#           nfev: 50
#            nit: 26
#         status: 0
#        success: True
#              x: array([2.51115640e-07, 3.93491174e-07])
# run time: 0.000s
#  final_simplex: (array([[2.51115640e-07, 3.93491174e-07],
#        [2.51117417e-07, 3.93428697e-07],
#        [2.51104290e-07, 3.93432465e-07]]), array([1725.39737427, 1725.39741302, 1725.39741671]))
#            fun: 1725.397374270815
#        message: 'Optimization terminated successfully.'
#           nfev: 50
#            nit: 26
#         status: 0
#        success: True
#              x: array([2.51115640e-07, 3.93491174e-07])

# %%
t = chem2.solution['t']
for k in chem2.data:
    if k!='t':
        p.plot(t, chem2.data[k], 'o', label = 'exp'+k)
        p.plot(t, chem2.solution[k], label = k)
p.legend()
p.title('model fitting')
# Out:
# Text(0.5, 1.0, 'model fitting')

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
@interact
def show(k = 1.0):
    chem2 = models.Chemistry()
    chem2.reaction('A+X=>B+Y', k = k)
    chem2.reaction('B+A=>C+Y', k = 1)
    chem2.initial_concentrations(A=1, X=1)
    chem2.time_stop = 100
    chem2.run()
# Out:
# run time: 0.061s
