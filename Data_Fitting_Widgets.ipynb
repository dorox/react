# %%
import models
import matplotlib.pyplot as p

# %%
chem1 = models.Chemistry()
chem1.reaction('A+X=>B+Y', k=1e-7)
chem1.reaction('B+A=>C+Y', k=1e-7)
chem1.initial_concentrations(A=90, X=200)
_=chem1.run()
# Out:
# run time: 0.002s

# %%
chem1.import_data('data/Expt1.csv')

# %%
chem1.plot('A', 'B', 'C')

# %%
chem1.rate_constants = [1e-7,1e-9]
chem1.rate_constants
# Out:
# [1e-07, 1e-09]

# %%
_=chem1.run()
# Out:
# run time: 0.002s

# %%
chem1.plot('A', 'B', 'C')

# %%
chem1.rate_constants = [2.30600665e-07, 3.69897732e-07]
_=chem1.run()
# Out:
# run time: 0.004s

# %%
chem1.fit()
# Out:
#  final_simplex: (array([[2.41466409e-07, 3.06837027e-07],
#        [2.41474474e-07, 3.06857375e-07],
#        [2.41470965e-07, 3.06943125e-07]]), array([970.70761256, 970.70761541, 970.70766627]))
#            fun: 970.7076125575504
#        message: 'Optimization terminated successfully.'
#           nfev: 90
#            nit: 45
#         status: 0
#        success: True
#              x: array([2.41466409e-07, 3.06837027e-07])
# run time: 0.002s
#  final_simplex: (array([[2.41466409e-07, 3.06837027e-07],
#        [2.41474474e-07, 3.06857375e-07],
#        [2.41470965e-07, 3.06943125e-07]]), array([970.70761256, 970.70761541, 970.70766627]))
#            fun: 970.7076125575504
#        message: 'Optimization terminated successfully.'
#           nfev: 90
#            nit: 45
#         status: 0
#        success: True
#              x: array([2.41466409e-07, 3.06837027e-07])

# %%
chem1.plot('A', 'B', 'C')

# %%
import ipywidgets as widgets
import numpy as np
from ipywidgets import interact, interact_manual
chem2 = models.Chemistry()
chem2.reaction('A+X=>B+Y', k = 1)
chem2.reaction('B+A=>C+Y', k = 1)
chem2.initial_concentrations(A = 1, X =1)

# %%
@interact
def show(k1 = (0,1,0.01), k2 = (0,1,0.01)):
    chem2.rate_constants = [k1, k2]
    chem2.run()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='k1', max=1.0, step=0.01), FloatSlider(value=0.0, des…
