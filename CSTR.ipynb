# %%
import matplotlib.pyplot as p
import numpy as np
from importlib import reload

import models
import tools

# %%
reload(models)
reload(tools)
# Out:
# <module 'tools' from 'C:\\Users\\id814\\jupyter\\react\\tools.py'>

# %%
r = models.CSTR(q=0.5, V=5)
r.inlet(A = tools.exponential(t1=20, y_tot=0.01, c=0.5))

# %%
_=r.run()
# Out:
# run time: 0.294s

# %%
t=np.linspace(0,100, 10000)
r.initial_values['A']
np.trapz(r.initial_values['A'](t), t)
# Out:
# 0.009984545343107344

# %%
c = models.Chemistry()
c.reaction('A=>B')
c.initial_concentrations(A=1)
_=c.run()
# Out:
# run time: 0.181s

# %%
r = models.CSTR(q=1, V=10)
r.inlet(A = tools.rect())
c = models.Chemistry()
c.reaction('A=>B')
r.add(c)
r.run()
# Out:
# run time: 0.415s
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 6092
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 1.00000000e-06, 1.10000000e-05, ...,
#        9.98893899e+01, 9.99893899e+01, 1.00000000e+02])
#  t_events: None
#         y: array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.20569220e-40, 5.55927091e-40, 5.49476522e-40],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.14299470e-04, 2.12167154e-04, 2.11942162e-04]])

# %%
r.import_data('data/cstr_pulse.csv')

# %%
r.q
# Out:
# 1

# %%
def test1(function):
    def wrapper():
        print('before fun')
        function()
        print('after fun')
    return wrapper

@test1
def test2():
    print('test2')
    
test2()
# Out:
# before fun
# test2
# after fun

# %%
class myclass:
    def ode(self):
        print('ode')
    
    def redefine_ode(self):
        def ode_new(self):
            print('new ode')
        self.ode = ode_new

# %%
mc = myclass()
mc.ode()
mc.redefine_ode()
mc.ode()
# Out:
# ode
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-0a52b4ab668e> in <module>
#       2 mc.ode()
#       3 mc.redefine_ode()
# ----> 4 mc.ode()
#
# TypeError: ode_new() missing 1 required positional argument: 'self'

# %%
def test(**kwargs):
#     for a in args:
#         print(a)
    for k, v in kwargs.items():
        print(k, v)

# %%
test(A=1)
# Out:
# A 1

# %%
d= dict()
len(d)
# Out:
# 0
