# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as p

# %%
def ode(t,c):
    x = c[0]
    y = c[1]
    a=1
    b=1.7
    dxdt = a+x**2*y-b*x-x
    dydt = b*x-x**2*y
    return [dxdt, dydt]

# %%
sol = solve_ivp(ode, (0,100), (1,1), max_step=0.1)

# %%
t = sol.t
x = sol.y[0]
y = sol.y[1]

# %%
p.plot(t,x)
p.plot(t,y)

# %%
p.plot(x,y)
