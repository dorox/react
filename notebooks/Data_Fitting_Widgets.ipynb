# %%
# %cd ..
# Out:
# C:\Users\id814\jupyter\react

# %%
import react
import matplotlib.pyplot as p

# %%
from importlib import reload
reload(react)
models = react.models

# %%
chem1 = models.Chemistry()
chem1.reaction('A+X=>B+Y', k=1)
chem1.reaction('B+A=>C+Y', k=1)
chem1.initial_concentrations(A=1, X=1)
_=chem1.run()
# Out:
# run time: 0.358s

# %%
chem1.plot('A', 'B')

# %%
chem1.import_data('data/Expt1.csv')

# %%
chem1.plot('A', 'B', 'C')

# %%
chem1.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-dc5da13d009f> in <module>
# ----> 1 chem1.run()
#
# ~\jupyter\react\react\lib\models.py in run(self, plot)
#      87                 events = self.events,
#      88                 # atol=1e-9,
# ---> 89                 # rtol=1e-7,
#      90                 )
#      91
#
# c:\program files\python37\lib\site-packages\scipy\integrate\_ivp\ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, **options)
#     479     status = None
#     480     while status is None:
# --> 481         message = solver.step()
#     482
#     483         if solver.status == 'finished':
#
# c:\program files\python37\lib\site-packages\scipy\integrate\_ivp\base.py in step(self)
#     180         else:
#     181             t = self.t
# --> 182             success, message = self._step_impl()
#     183
# ...

# %%
chem1.plot('A', 'B', 'C')

# %%
_=chem1.fit()
# Out:
#  final_simplex: (array([[0.95256046, 1.0043376 ],
#        [0.95256159, 1.00437821],
#        [0.95256444, 1.00434882]]), array([121337.40591968, 121337.40599068, 121337.40600031]))
#            fun: 121337.40591968337
#        message: 'Optimization terminated successfully.'
#           nfev: 82
#            nit: 44
#         status: 0
#        success: True
#              x: array([0.95256046, 1.0043376 ])
# run time: 0.030s

# %%
chem1.plot('A', 'B', 'C')

# %%
import ipywidgets as widgets
import numpy as np
from ipywidgets import interact, interact_manual
chem2 = models.Chemistry()
chem2.reaction('A+X=>B+Y', k = 1e-10)
chem2.reaction('B+A=>C+Y', k = 1e-10)
chem2.initial_concentrations(A = 1, X =100)
chem2.import_data('data/Expt1.csv')

# %%
@interact
def show(k1 = (0,1,1e-7), k2 = (0,1,1e-7)):
    chem2.rate_constants = [k1, k2]
    _=chem2.run()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='k1', max=1.0, step=1e-07), FloatSlider(value=0.0, de…

# %%
chem2.rate_constants = [1e-6, 1e-6]

# %%
chem2.run()
# Out:
# run time: 0.013s
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 69
#      njev: 1
#       nlu: 11
#       sol: None
#    status: 0
#   success: True
#         t: array([  600.,  1200.,  1800.,  2400.,  3000.,  3660.,  4360.,  4840.,
#         5440.,  6000.,  6600.,  7200.,  7920.,  8400.,  9060.,  9660.,
#        10200., 10800., 11340., 12000., 12640., 13320., 13840., 14400.,
#        15000., 15680., 16200., 16960., 17400., 18000., 18600., 19200.,
#        19840., 20440., 21000.])
#  t_events: None
#         y: array([[ 86.        ,  80.99369274,  76.28915772,  71.87528719,
#          67.73849927,  63.49003192,  59.3070211 ,  56.6183323 ,
#          53.44988956,  50.67356387,  47.87993824,  45.26096287,
#          42.3315312 ,  40.49889367,  38.12473323,  36.10303094,
#          34.38707589,  32.58784448,  31.05911075,  29.29969237,
#          27.69956417,  26.10786756,  24.96082925,  23.78744725,
# ...

# %%
chem2.fit()
# Out:
#  final_simplex: (array([[5.51345891e-07, 2.95808033e-07],
#        [5.51337620e-07, 2.95731520e-07],
#        [5.51368992e-07, 2.95733470e-07]]), array([838.99401384, 838.99402186, 838.99402788]))
#            fun: 838.9940138442298
#        message: 'Optimization terminated successfully.'
#           nfev: 83
#            nit: 44
#         status: 0
#        success: True
#              x: array([5.51345891e-07, 2.95808033e-07])
# run time: 0.009s
#  final_simplex: (array([[5.51345891e-07, 2.95808033e-07],
#        [5.51337620e-07, 2.95731520e-07],
#        [5.51368992e-07, 2.95733470e-07]]), array([838.99401384, 838.99402186, 838.99402788]))
#            fun: 838.9940138442298
#        message: 'Optimization terminated successfully.'
#           nfev: 83
#            nit: 44
#         status: 0
#        success: True
#              x: array([5.51345891e-07, 2.95808033e-07])
