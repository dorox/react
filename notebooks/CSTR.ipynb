# %%
import matplotlib.pyplot as p
import numpy as np
from importlib import reload

import models
import tools

# %%
reload(models)
reload(tools)
# Out:
# <module 'tools' from 'C:\\Users\\id814\\jupyter\\react\\tools.py'>

# %%
r = models.CSTR(q=0.5, V=5)
r.inlet(A = tools.gaussian())

# %% [markdown]
# Make distinctive A and inlet A

# %%
_=r.run()
# Out:
# run time: 0.038s

# %%
print(np.trapz([r.initial_values['A'](t) for t in np.arange(0,100,0.01)],np.arange(0,100,0.01)))
print(np.trapz(r.solution['A'], r.solution['t']))
# Out:
# 1.0
# 1.000821694025767

# %%
c = models.Chemistry()
c.reaction('A=>B', k=0.1)
c.initial_concentrations(A=1)
_=c.run()
# Out:
# run time: 0.018s

# %%
#r = models.CSTR(q=1, V=10)
#r.inlet(A = tools.step())
c = models.Chemistry()
c.reaction('A=>B')
r.add(c)
r.run()
# Out:
# run time: 0.040s
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 251
#      njev: 4
#       nlu: 29
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 1.00000000e-06, 2.00000000e-06, 1.20000000e-05,
#        2.20000000e-05, 1.22000000e-04, 2.22000000e-04, 1.22200000e-03,
#        2.22200000e-03, 1.22220000e-02, 2.22220000e-02, 1.22222000e-01,
#        2.22222000e-01, 1.22222200e+00, 2.22222200e+00, 1.22222220e+01,
#        1.42222220e+01, 1.48208629e+01, 1.54195038e+01, 1.57531085e+01,
#        1.60867132e+01, 1.64111416e+01, 1.66073439e+01, 1.68035463e+01,
#        1.69270197e+01, 1.70504932e+01, 1.71739667e+01, 1.73368118e+01,
#        1.74996570e+01, 1.76625021e+01, 1.78253472e+01, 1.80610649e+01,
#        1.82967826e+01, 1.85325002e+01, 1.87124263e+01, 1.88923524e+01,
#        1.90722784e+01, 1.92522045e+01, 1.94321306e+01, 1.96346525e+01,
#        1.98371745e+01, 2.00396965e+01, 2.02422184e+01, 2.04447404e+01,
#        2.06472623e+01, 2.08507476e+01, 2.10542329e+01, 2.12577181e+01,
#        2.14612034e+01, 2.16646887e+01, 2.18681739e+01, 2.20913035e+01,
#        2.23144330e+01, 2.25375625e+01, 2.27606921e+01, 2.29838216e+01,
#        2.32069511e+01, 2.34960283e+01, 2.37296173e+01, 2.39632063e+01,
#        2.41967953e+01, 2.44303843e+01, 2.46639734e+01, 2.48975624e+01,
#        2.52155136e+01, 2.55334649e+01, 2.58514161e+01, 2.61693674e+01,
#        2.64873186e+01, 2.68668640e+01, 2.72464094e+01, 2.76259547e+01,
#        2.80055001e+01, 2.83850455e+01, 2.89500378e+01, 2.95150300e+01,
#        3.00800223e+01, 3.06450145e+01, 3.12100068e+01, 3.23306673e+01,
#        3.34513279e+01, 3.45719884e+01, 3.56926489e+01, 3.73222412e+01,
#        3.89518334e+01, 4.05814256e+01, 4.22110179e+01, 4.44474554e+01,
#        4.66838930e+01, 4.89203306e+01, 5.11567681e+01, 5.33932057e+01,
#        5.59238164e+01, 5.84544271e+01, 6.09850379e+01, 6.35156486e+01,
#        6.60462593e+01, 6.90951719e+01, 7.21440846e+01, 7.51929973e+01,
#          9.56670638e-05,  1.54421692e-04,  2.45458738e-04,
#          3.83442651e-04,  7.06718327e-04,  1.24770401e-03,
#          2.10833505e-03,  3.05584025e-03,  4.31911551e-03,
#          5.95438610e-03,  8.00989110e-03,  1.05195059e-02,
#          1.39034797e-02,  1.78590750e-02,  2.23198803e-02,
#          2.71751915e-02,  3.22784034e-02,  3.74604232e-02,
#          4.25697582e-02,  4.74150461e-02,  5.18553112e-02,
#          5.57855740e-02,  5.91412933e-02,  6.18973036e-02,
#          6.42411985e-02,  6.59227175e-02,  6.70138442e-02,
#          6.75979235e-02,  6.77597199e-02,  6.75789043e-02,
#          6.69503772e-02,  6.61969464e-02,  6.52827894e-02,
#          6.42510805e-02,  6.31356987e-02,  6.19627709e-02,
#          6.07523726e-02,  5.90722776e-02,  5.73796620e-02,
#          5.56938572e-02,  5.40282044e-02,  5.23917875e-02,
#          5.04848320e-02,  4.86338149e-02,  4.68416942e-02,
#          4.51096982e-02,  4.34379011e-02,  4.10591447e-02,
#          3.88076800e-02,  3.66779414e-02,  3.46641433e-02,
#          3.27604778e-02,  2.92881081e-02,  2.61838814e-02,
#          2.34086224e-02,  2.09273583e-02,  1.77818710e-02,
#          1.51093869e-02,  1.28383922e-02,  1.09085702e-02,
#          8.72232035e-03,  6.97359545e-03,  5.57546097e-03,
#          4.45783329e-03,  3.56430398e-03,  2.76702452e-03,
#          2.14794457e-03,  1.66739623e-03,  1.29442293e-03,
#          1.00489681e-03,  7.40533065e-04,  5.45616891e-04,
#          4.02026753e-04,  2.96274765e-04,  2.18352432e-04,
#          1.46266460e-04,  9.78686896e-05,  6.55036836e-05,
#          4.38944208e-05,  3.33838472e-05]])

# %%
r.import_data('data/cstr_pulse.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-398b2fbadbbe> in <module>
# ----> 1 r.import_data('data/cstr_pulse.csv')
#
# ~\jupyter\react\models.py in import_data(self, file_name)
#      40         '''
#      41         #TODO: set initial conditions as in imported data
# ---> 42         data = get_data(file_name)
#      43         self.data = data
#      44         if self.data:
#
# NameError: name 'get_data' is not defined

# %%
import ipywidgets as widgets
import numpy as np
from ipywidgets import interact, interact_manual

@interact
def reactor(V=(0.01,10,0.1), sig = (1,10,0.1)):
    r2 = models.CSTR(0.4167,V)
    r2.inlet(A=tools.gaussian(t1=20, sig=sig))
    r2.run()
# Out:
# interactive(children=(FloatSlider(value=4.91, description='V', max=10.0, min=0.01), FloatSlider(value=5.0, des…

# %%
r2 = models.CSTR(0.4167,1)
r2.inlet(A=tools.gaussian(t1=20, sig=1))
_=r2.run()
# Out:
# run time: 0.037s

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\id814\\jupyter\\react',
#  'c:\\program files\\python37\\python37.zip',
#  'c:\\program files\\python37\\DLLs',
#  'c:\\program files\\python37\\lib',
#  'c:\\program files\\python37',
#  '',
#  'C:\\Users\\id814\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'c:\\program files\\python37\\lib\\site-packages',
#  'c:\\program files\\python37\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\id814\\.ipython']
