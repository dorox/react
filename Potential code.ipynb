# %%
from models import *
import matplotlib.pyplot as p

# %%
chem1 = Chemistry()
chem1.reaction('A+X=>B+Y', k = 1e-5)
chem1.reaction('B+A=>C+Y', k = 1e-7)
chem1.initial_concentrations(A=90, X=200)
chem1.time_stop = 2000
chem1.run()
# Out:
# run time: 0.002s
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 62
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 5.55551080e-03, 6.11106188e-02, 6.16661699e-01,
#        6.17217250e+00, 6.17272805e+01, 2.73517480e+02, 5.99074366e+02,
#        1.06280261e+03, 1.68289060e+03, 2.00000000e+03])
#  t_events: None
#         y: array([[9.00000000e+01, 8.99990000e+01, 8.99890011e+01, 8.98890998e+01,
#         8.88988376e+01, 7.98028798e+01, 5.49096189e+01, 3.33199836e+01,
#         1.77946934e+01, 8.29058516e+00, 5.70304972e+00],
#        [2.00000000e+02, 1.99999000e+02, 1.99989001e+02, 1.99889100e+02,
#         1.98898868e+02, 1.89805569e+02, 1.64944483e+02, 1.43419276e+02,
#         1.27967464e+02, 1.18522243e+02, 1.15952795e+02],
#        [0.00000000e+00, 9.99983864e-04, 1.09989337e-02, 1.10899632e-01,
# ...

# %%
chem1.import_data('data/Expt1.csv')

# %%
chem1.plot(all = True)

# %%
chem1.run()
# Out:
# run time: 0.008s
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 152
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([  600.,  1200.,  1800.,  2400.,  3000.,  3660.,  4360.,  4840.,
#         5440.,  6000.,  6600.,  7200.,  7920.,  8400.,  9060.,  9660.,
#        10200., 10800., 11340., 12000., 12640., 13320., 13840., 14400.,
#        15000., 15680., 16200., 16960., 17400., 18000., 18600., 19200.,
#        19840., 20440., 21000.])
#  t_events: None
#         y: array([[9.00000000e+01, 3.32756113e+01, 1.49399391e+01, 7.21200496e+00,
#         3.59589300e+00, 1.69838414e+00, 7.73921378e-01, 4.53779168e-01,
#         2.32356367e-01, 1.24637413e-01, 6.40903696e-02, 3.28513793e-02,
#         1.47657755e-02, 8.68200064e-03, 4.16471785e-03, 2.13998631e-03,
#         1.17647924e-03, 6.02984648e-04, 3.32130167e-04, 1.59211753e-04,
# ...

# %%
m = myclass()
# Out:
# 0

# %%
chem1.time_stop
# Out:
# 21000.0

# %%
from collections import OrderedDict
d = OrderedDict().fromkeys(range(5), 'hello')

# %%
l= np.arange(10)/2
y = np.exp(l)-1
p.plot(l, y)
y[0]
# Out:
# 0.0

# %%
reactor = CSTR(q=1, V=1, c_in=1)
reactor.c_in = pulse(N=1)
reactor.run()
reactor.import_data('filename')
reactor.fit()
