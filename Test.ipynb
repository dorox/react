# %%
import numpy as np
import matplotlib.pyplot as p
import models
chem = models.Chemistry()

# %%
chem.reaction('A+B<=>2C', k=0.1)
chem.reaction('2C+A=>2D')

# %%
chem.time_stop = 10
chem.c0 = [1,1,0,0]
t, c = chem.ode_solver()

# %%
for i in c:
    p.plot(t, i)

# %%
p.plot(t, sum(c))
